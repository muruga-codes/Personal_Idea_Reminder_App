# %% [markdown]
# Create and Write to a File

# %%
with open("../data/idea.txt", "w") as file:
    file.write("AI assitance")

# %%
import os
print(os.getcwd())
# Out:
# c:\Personal_Idea_Reminder_App\notebook

# %% [markdown]
# Read from a File

# %%
with open("../data/idea.txt","r") as file:
    print(file.read())
# Out:
# AI assitance

# %% [markdown]
# Append Data

# %%
with open("../data/idea.txt","a") as file:
    file.write("\nweather app")

# %% [markdown]
# Save User Ideas

# %%
idea=input("enter your idea:")

with open("../data/idea.txt","a") as file:
    file.write(idea+"\n")
print("idea saved")
# Out:
# idea saved
